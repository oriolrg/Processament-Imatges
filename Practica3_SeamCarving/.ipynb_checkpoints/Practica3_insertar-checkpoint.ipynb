# %%
## PART 3 - SEAM CARVING - SINTESIS D'IMATGES.
# %matplotlib inline

# %%
# carreguem totes les llibreries necesaries per a la practica
from skimage import data, draw, color, data, restoration, filters,transform, util
from scipy import misc, fftpack, signal
from scipy.misc import imresize
from scipy import ndimage as nd
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageEnhance
import matplotlib.animation as animation
import scipy

# %%
#normalitzacio d'imatge
def normalitzar(imatge):
    return np.real((imatge - np.min(imatge)) * 256 / (np.max(imatge) - np.min(imatge)))

# %%
rgb =  plt.imread('iberia.jpg')
img = color.rgb2gray(rgb)
img = util.img_as_float(img)

fig = plt.figure(1) 
plt.subplot(1,2,1)
plt.imshow(rgb.astype('uint8'))
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(normalitzar(img), cmap="gray")
plt.title('Escala de gris')
plt.gcf().set_size_inches((20,20))
plt.show()

# %%
# Funcio que trobara els gradients de l'imatge
def gradient(img):
    img = color.rgb2gray(img)
    gx, gy = np.gradient(img)
    grad = np.sqrt(gx*gx + gy*gy)
    return grad

# Calculem el gradient i mostrem el gradient de l'imatge
grad = gradient(img)
fig = plt.figure(2) 
plt.title('Contorns imatge')
plt.imshow(grad, cmap="gray" )
plt.show()

# %%
#Calcul matriu d'energia que acomulada te cada zona
def energia(imatge):
    height,width = imatge.shape
    energia=np.zeros(imatge.shape)
    #asignem la primera linea igual que la imatge que tenim
    energia[0]=imatge[0]   
    for x in range(1,height):
        for y in range(0,width):
            if y == 0:#inici de la imatge
                min_val = min( energia[x-1, y], energia[x-1, y+1] )
            elif y < width - 2:#abans del final de la imatge
                min_val = min( energia[x-1, y], energia[x-1, y+1] )
                min_val = min( min_val, energia[x-1, y-1] )
            else:#final de la imatge
                min_val = min( energia[x-1, y], energia[x-1, y-1] )
            energia[x,y] = imatge[x,y] + min_val#valor acomulat d'energia
    return energia

# %%
# Calculem la matriu acumulada, es a dir, l'energia
grad = normalitzar(grad)
E = energia(grad)
fig = plt.figure(3) 
plt.title('Acumulacio energia')
plt.imshow(E, cmap="gray" )
plt.show()

# %%
# El calcul del tall vertical hem de buscar el cami amb cost minim. BACKTRACKING
# Aquest tall pot ser vertical o horitzontal, es un camí de pixels connectats. En el nostre cas l'apliquem vertical
# La función de importancia / energía valora un píxel mediante la medición de su contraste con sus píxeles vecinos.
# Des de la imatge en escala de grisos retornarem el tall vertical mes baix com a llista de pixels

def buscar_seams(im, it):
    '''
    Takes a grayscale img and returns a list of the @it lowest energy vertical seams as a list of pixels (2-tuples). 
    This implements the dynamic programming seam-find algorithm. For an m*n picture, this algorithm
    takes O(m*n) time 
    @im: a grayscale image
    @it: iterations to do as number of seams to get
    '''
    assert len(im.shape) == 2
    
    im_width, im_height = im.shape
    cost = energia(gradient(im))
    
    paths = []
    visited = []
    
    for i in xrange(it):
        min_val = 1e1000
        path = []
        
        #Get the min value from last energy row not visited yet.
        for y in xrange(im_height):
            if cost[im_width-1,y] < min_val and y not in visited :
                min_val = cost[im_width-1,y]
                min_ptr = y
        #we will take the start path index and save it to avoid repeating same seam without deleting it.        
        visited.append(min_ptr)
        pos = (im_width-1, min_ptr)
        path.append(pos)
        
        while pos[0] != 0:
            val = cost[pos] - grad[pos]
            x,y = pos
            if y == 0:
                if val == cost[x-1,y+1]:
                    pos = (x-1,y+1) 
                else:
                    pos = (x-1,y)
            elif y <= im_height - 2:
                if val == cost[x-1,y+1]:
                    pos = (x-1,y+1) 
                elif val == cost[x-1,y]:
                    pos = (x-1,y)
                else:
                    pos = (x-1,y-1)
            else:
                if val == cost[x-1,y]:
                    pos = (x-1,y)
                else:
                    pos = (x-1,y-1) 

            path.append(pos)
            #print "Reconstruction Complete."
        
        print "iteration",i,"\tpath @",path[0][1]
        paths.append(path)
  

    return paths

# %%
def vector_avg(u, v):
    '''
    Returns the component average between each vector
    @u: input vector u
    @v: input vector v
    '''
    w = u.astype('uint16') #change type to avoid overflow 
    for i in range(len(w)):
        w[i] = (w[i] + v[i])/2

    return w.astype('uint8')

def add_vertical_seam(img, path):
    '''
    Adds the pixels in a vertical path from img
    @img: an input img
    @path: pixels to delete in a vertical path
    '''
    #print "Adding Vertical Seam..."
    img_height, img_width = img.shape[:2]
    i = np.zeros((img_height, img_width+1, img.shape[2]))
    
    path_set = set(path)
    seen_set = set()
    
    for x in xrange(img_height):
        for y in xrange(img_width):
            if (x,y) not in path_set and x not in seen_set:
                i[x,y] = img[x,y]
            elif (x,y) in path_set and x not in seen_set:
                i[x,y] = img[x,y]
                seen_set.add(x)
                if y <= img_width - 2:
                    i[x,y+1] = vector_avg(img[x,y], img[x,y+1])
                else:
                    i[x,y+1] = vector_avg(img[x,y], img[x,y-1])
            else:
                i[x,y+1] = img[x,y]

    #print "Addition Complete."
    return i

def mark_seam (mat, path, mark_as='red'):
    #Dono maxim valor al canal corresponent al color escollit a tots els pixels del path que ens marca el cami a borrar
    for i in path:
        if mark_as == 'red':
            mat[i] = (255,0,0)
        elif mark_as == 'green':
            mat[i] = (0,255,0)
        elif mark_as == 'blue':
            mat[i] = (0,0,255)
        elif mark_as == 'white':
            mat[i] = (255,255,255)
        elif mark_as == 'black':
            mat[i] = (0,0,0)
    
    return mat;

# %%
def carving(imatge,iterations):
    #result = rgb.copy();
    #seams = []

    #gray = color.rgb2gray(rgb)
    #paths = find_vertical_seams(gray, it)
    #for p in paths:
    #    rgb = mark_seam(rgb, p, 'blue')
    #    seams.append([plt.imshow(rgb.astype('uint8'))])
    #    result = add_vertical_seam(result, p)
    gray = color.rgb2gray(imatge)
    paths = buscar_seams(gray, iterations)
    rgb = imatge
    seams = []


    return result, seams;

# %%
rgb =  plt.imread('iberia.jpg')
result, seams = carving(rgb.copy(), 100);
print result.shape
# Out:
# iteration 0 	path @ 985
# iteration 1 	path @ 1000
# iteration 2 	path @ 986
# iteration 3 	path @ 998
# iteration 4 	path @ 989
# iteration 5 	path @ 997
# iteration 6 	path @ 1004
# iteration 7 	path @ 999
# iteration 8 	path @ 1001
# iteration 9 	path @ 984
# iteration 10 	path @ 993
# iteration 11 	path @ 1002
# iteration 12 	path @ 987
# iteration 13 	path @ 994
# iteration 14 	path @ 981
# iteration 15 	path @ 990
# iteration 16 	path @ 992
# iteration 17 	path @ 988
# iteration 18 	path @ 1005
# iteration 19 	path @ 995
# iteration 20 	path @ 996
# iteration 21 	path @ 983
# iteration 22 	path @ 991
# iteration 23 	path @ 980
# iteration 24 	path @ 1003
# iteration 25 	path @ 1017
# iteration 26 	path @ 1010
# iteration 27 	path @ 1016
# iteration 28 	path @ 1009
# iteration 29 	path @ 1006
# iteration 30 	path @ 1015
# iteration 31 	path @ 1023
# iteration 32 	path @ 1013
# iteration 33 	path @ 1021
# iteration 34 	path @ 982
# iteration 35 	path @ 1019
# iteration 36 	path @ 1018
# iteration 37 	path @ 1014
# iteration 38 	path @ 1022
# iteration 39 	path @ 1020
# iteration 40 	path @ 1008
# iteration 41 	path @ 1007
# iteration 42 	path @ 972
# iteration 43 	path @ 1011
# iteration 44 	path @ 979
# iteration 45 	path @ 973
# iteration 46 	path @ 1012
# iteration 47 	path @ 974
# iteration 48 	path @ 978
# iteration 49 	path @ 916
# iteration 50 	path @ 975
# iteration 51 	path @ 977
# iteration 52 	path @ 901
# iteration 53 	path @ 903
# iteration 54 	path @ 976
# iteration 55 	path @ 902
# iteration 56 	path @ 904
# iteration 57 	path @ 917
# iteration 58 	path @ 905
# iteration 59 	path @ 971
# iteration 60 	path @ 970
# iteration 61 	path @ 965
# iteration 62 	path @ 906
# iteration 63 	path @ 913
# iteration 64 	path @ 900
# iteration 65 	path @ 915
# iteration 66 	path @ 912
# iteration 67 	path @ 897
# iteration 68 	path @ 899
# iteration 69 	path @ 898
# iteration 70 	path @ 914
# iteration 71 	path @ 893
# iteration 72 	path @ 969
# iteration 73 	path @ 910
# iteration 74 	path @ 921
# iteration 75 	path @ 966
# iteration 76 	path @ 968
# iteration 77 	path @ 892
# iteration 78 	path @ 922
# iteration 79 	path @ 964
# iteration 80 	path @ 907
# iteration 81 	path @ 924
# iteration 82 	path @ 925
# iteration 83 	path @ 967
# iteration 84 	path @ 911
# iteration 85 	path @ 961
# iteration 86 	path @ 919
# iteration 87 	path @ 923
# iteration 88 	path @ 932
# iteration 89 	path @ 896
# iteration 90 	path @ 918
# iteration 91 	path @ 891
# iteration 92 	path @ 895
# iteration 93 	path @ 894
# iteration 94 	path @ 890
# iteration 95 	path @ 933
# iteration 96 	path @ 934
# iteration 97 	path @ 930
# iteration 98 	path @ 926
# iteration 99 	path @ 885
# iteration 100 	path @ 929
# iteration 101 	path @ 927
# iteration 102 	path @ 886
# iteration 103 	path @ 879
# iteration 104 	path @ 962
# iteration 105 	path @ 931
# iteration 106 	path @ 908
# iteration 107 	path @ 928
# iteration 108 	path @ 882
# iteration 109 	path @ 909
# iteration 110 	path @ 878
# iteration 111 	path @ 920
# iteration 112 	path @ 880
# iteration 113 	path @ 875
# iteration 114 	path @ 877
# iteration 115 	path @ 887
# iteration 116 	path @ 874
# iteration 117 	path @ 876
# iteration 118 	path @ 963
# iteration 119 	path @ 960
# iteration 120 	path @ 881
# iteration 121 	path @ 883
# iteration 122 	path @ 884
# iteration 123 	path @ 940
# iteration 124 	path @ 873
# iteration 125 	path @ 871
# iteration 126 	path @ 957
# iteration 127 	path @ 959
# iteration 128 	path @ 869
# iteration 129 	path @ 872
# iteration 130 	path @ 888
# iteration 131 	path @ 941
# iteration 132 	path @ 889
# iteration 133 	path @ 937
# iteration 134 	path @ 938
# iteration 135 	path @ 939
# iteration 136 	path @ 953
# iteration 137 	path @ 936
# iteration 138 	path @ 935
# iteration 139 	path @ 868
# iteration 140 	path @ 870
# iteration 141 	path @ 954
# iteration 142 	path @ 958
# iteration 143 	path @ 956
# iteration 144 	path @ 955
# iteration 145 	path @ 943
# iteration 146 	path @ 944
# iteration 147 	path @ 945
# iteration 148 	path @ 942
# iteration 149 	path @ 946
# (682L, 1174L, 3L)

# %%
ani = animation.ArtistAnimation(fig, seams, interval=100, blit=True, repeat_delay=1000);
plt.show();
fig = plt.figure(4) 
plt.imshow(result.astype('uint8'))
plt.title('Seam Carving -'+ str(N) + ' additions')
plt.axis('off')
plt.gcf().set_size_inches((15,15))
fig.tight_layout()
